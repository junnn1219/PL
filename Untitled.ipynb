# %%
import pandas as pd

data = pd.read_csv("hw1111.csv")
data
# Out:
#      姓名  居住地   職業   姓別  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0   郭元瑜  新北市    工    W         NaN         NaN         NaN         NaN
# 1   劉家齊  台北市    教    M         NaN         NaN         NaN         NaN
# 2   楊亞妤  基隆市    工    M         NaN         NaN         NaN         NaN
# 3   蔡至偉  台北市    商    M         NaN         NaN         NaN         NaN
# 4   林慧敏  新北市    工    W         NaN         NaN         NaN         NaN
# 5   許聖豪  桃園縣    教    M         NaN         NaN         NaN         NaN
# 6   潘彥伶  台北市    工    W         NaN         NaN         NaN         NaN
# 7   張建志  新北市    工    W         NaN         NaN         NaN         NaN
# 8   盧小薔  新北市    教    M         NaN         NaN         NaN         NaN
# 9   歐晏中  新北市    軍    M         NaN         NaN         NaN         NaN
# 10  黃文睿  台北市    公    W         NaN         NaN         NaN         NaN
# 11  楊若玲  新北市    農    M         NaN         NaN         NaN         NaN
# ...
