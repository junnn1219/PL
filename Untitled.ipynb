# %%
import pandas as pd

data = pd.read_csv("hw1111.csv")
data
# Out:
#     Unnamed: 0 Unnamed: 1   家長 Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0          NaN         姓名  居住地         職業         姓別         NaN         NaN
# 1          NaN        郭元瑜  新北市          工          W         NaN         NaN
# 2          NaN        劉家齊  台北市          教          M         NaN         NaN
# 3          NaN        楊亞妤  基隆市          工          M         NaN         NaN
# 4          NaN        蔡至偉  台北市          商          M         NaN         NaN
# 5          NaN        林慧敏  新北市          工          W         NaN         NaN
# 6          NaN        許聖豪  桃園縣          教          M         NaN         NaN
# 7          NaN        潘彥伶  台北市          工          W         NaN         NaN
# 8          NaN        張建志  新北市          工          W         NaN         NaN
# 9          NaN        盧小薔  新北市          教          M         NaN         NaN
# 10         NaN        歐晏中  新北市          軍          M         NaN         NaN
# ...
